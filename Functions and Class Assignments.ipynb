# %%
# Logic # Create a class and function, and list out the items in the list

# %%
lists = ('MachineLearning','NeuralNetworks','Vision','Robotics','SpeechProcessing','NaturalLanguageProcessing')
print ("Sub-fields in AI are:")
for AI in lists:
    print (AI)
# Out:
# Sub-fields in AI are:
# MachineLearning
# NeuralNetworks
# Vision
# Robotics
# SpeechProcessing
# NaturalLanguageProcessing

# %%
# Create a class and function, and list out the items in the list

# %%
class SubfieldsInAI ():
    def Subfields():
        lists = ('MachineLearning','NeuralNetworks','Vision','Robotics','SpeechProcessing','NaturalLanguageProcessing')
        print ("Sub-fields in AI are:")
        for AI in lists:
            print (AI)            
        message = print (AI)
        return message

# %%
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# MachineLearning
# NeuralNetworks
# Vision
# Robotics
# SpeechProcessing
# NaturalLanguageProcessing
# NaturalLanguageProcessing

# %%
# Create a function that checks whether the given number is Odd or Even

# %%
number = int(input ("Enter the number:"))
if (number%2==1):
    print(number,"is ODD number")
else:
    print (number,"is Even number")
# Out:
# Enter the number: 10
# 10 is Even number

# %%
class OddEvenNumber():
    def OddEven():
        number = int(input ("Enter the number:"))
        if (number%2==1):
            print (number,"is ODD number")
        else:
            print (number,"is Even number")

# %%
OddEvenNumber.OddEven()
# Out:
# Enter the number: 24
# 24 is Even number
# 24 is Even number

# %%
# Create a function that tells elegibility of marriage # for male and female according to their age limit like 21 # for male and 18 for female

# %%
gender = input ("Enter your Gender:")
age = int(input ("Enter your age:"))
class ElegiblityForMarriage():
    def Elegible(gender,age):
        if (gender=="male" and age>21):
            print("Eligible for Marriage")
        elif (gender=="male" and age<21):
            print("NOT Eligible for Marriage")
        elif (gender=="female" and age>18):
            print("Eligible for Marriage")
        elif (gender=="female" and age<21):
            print("NOT Eligible for Marriage")
        else:
            print ("Invalid Input")
    
ElegiblityForMarriage.Elegible(gender,age)
# Out:
# Enter your Gender: male
# Enter your age: 34
# Eligible for Marriage

# %%
# calculate the percentage of your 10th mark

# %%
sub01 = int(input ("subject01 mark:"))
sub02 = int(input ("subject02 mark:"))
sub03 = int(input ("subject03 mark:"))
sub04 = int(input ("subject04 mark:"))
sub05 = int(input ("subject05 mark:"))
class FindPercent():
    def percentage():
        total = sub01+sub02+sub03+sub04+sub05
        percent = total/5
        print ("Total:",total)
        print ("Percentage:",percent)

FindPercent.percentage()
# Out:
# subject01 mark: 90
# subject02 mark: 80
# subject03 mark: 70
# subject04 mark: 60
# subject05 mark: 50
# Total: 350
# Percentage: 70.0

# %%
#print area and perimeter of triangle using class and functions

# %%
class triangle():
    def triangle():
        height = int(input ("Height:"))
        breadth = int(input ("Breadth:"))
        formula= (height*breadth)/2
        print ("Aread of Triangle:",formula)
        height1 = int(input ("Height1:"))
        height2 = int(input ("Height2:"))
        breadth1 = int(input ("Breadth1:"))
        perimeter= height1+height2+breadth1
        print ("Perimeter of Triangle:",perimeter)

triangle.triangle()
# Out:
# Height: 32
# Breadth: 34
# Aread of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth1: 4
# Perimeter of Triangle: 10
