# %%
# Problem 01 # Print 'CORRECT' if i == 10

# %%
number = int(input("Enter the number:"))
if (number==10):
    print("Correct")
else:
    print("Incorrect")
# Out:
# Enter the number: 12
# Incorrect

# %%
#Problem 02 # # Check the password, using if and else

# %%
password = input("Enter the Password:")
if (password=="HOPE@123"):
    print("Correct")
else:
    print("Incorrect")
# Out:
# Enter the Password: HOPE@123
# Correct

# %%
#Problem 03 # # Catagory the people by their age like children, adult, citizen, senior citizen...

# %%
age = int(input("Enter your age:"))
if(age<14):
    print("You are Children")
elif(age<30):
    print("Your are adult")
elif(age<65):
    print("You are Citizen")
elif(age>65):
    print("You are Senior Citizen")
# Out:
# Enter your age: 41
# You are Citizes

# %%
#Problem 04 ## Find whether given number is positive or negative

# %%
number = int(input("Enter your number:"))
if(number%2==0):
    print("Postive number")
else:
    print("Negative number")
# Out:
# Enter your number: 25
# Negative number

# %%
#Problem 05 # Check whether the given number is divisible by 5

# %%
number = int(input("Enter your number to check:"))
if(number%5==0):
    print("Given number is divisble by 5")
else:
    print("Given number is NOT Divisible by 5")
# Out:
# Enter your number to check: 43
# Given number is NOT Divisible by 5
