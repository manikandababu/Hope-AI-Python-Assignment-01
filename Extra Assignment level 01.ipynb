# %%
# Problem 01 # Print Statement

# %%
print ("HOPE AI")
# Out:
# HOPE AI

# %%
#Problem 02 # Buy Input

# %%
name=input("Enter your institute name:")
print(name)
# Out:
# Enter your institute name: HOPE AI
# HOPE AI

# %%
#Problem 03 # Buy Inputs

# %%
name = input("Enter your name:"),int(input("Enter your age:")),input("Enter your School name:"),input("Enter your degree:")
print(name)
# Out:
# Enter your name: Manikandababu
# Enter your age: 43
# Enter your School name: Velammal Vidhyashram
# Enter your degree: B.Tech Textile Technology
# ('Manikandababu', 43, 'Velammal Vidhyashram', 'B.Tech Textile Technology')

# %%
#Problem 04 # Addition

# %%
a = 43
print ("The given 01st number:",a)
b = 34
print ("The given 02nd number:",b)
ADD = a+b
print ("The Answer is:",ADD)
# Out:
# The given 01st number: 43
# The given 02nd number: 34
# The Answer is: 77

# %%
#problem 05 # Subtraction

# %%
a=43
print("The given 01st number:",a)
b=34
print ("The given 02nd number:",b)
Subs =a-b
print ("The Substracted value:",Subs)
# Out:
# The given 01st number: 43
# The given 02nd number: 34
# The Substracted value: 9

# %%
#problem 06 # Multiplication

# %%
a=63
print ("The given 01st value:",a)
b=97
print ("The given 02nd value:",b)
multiply = a*b
print ("The Multiply value =",multiply)
# Out:
# The given 01st value: 63
# The given 02nd value: 97
# The Multiply value = 6111

# %%
#Problem 07 #Division

# %%
a=76
print ("first number",a)
b=31
print ("second number",b)
division=a/b
print ("Division value",division)
# Out:
# first number 76
# second number 31
# Division value 2.4516129032258065

# %%
#problem 08 # Floor Divison

# %%
a=76
print ("first number",a)
b=31
print ("second number",b)
division=a//b
print ("Floor Division value",division)
# Out:
# first number 76
# second number 31
# Floor Division value 2

# %%
#Problem 09 # Modulo

# %%
a=76
print ("first number",a)
b=31
print ("second number",b)
Modulo=a%b
print ("Modulo value",Modulo)
# Out:
# first number 76
# second number 31
# Modulo value 14

# %%
#problem 10 #Power

# %%
a=4
print("a=",a)
b=4
print("b=",b)
power = pow (4,4)
print (power)
# Out:
# a= 4
# b= 4
# 256
