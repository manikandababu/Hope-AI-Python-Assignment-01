# %%
# print statement

# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
# Buy Input

# %%
name = input ("Enter your institute name?:")
print ()
# Out:
# Enter your institute name?: Hope AI

# %%
# Buy Inputs - Multiples

# %%
name = input ("Enter your name:")
age = input ("Enter your age:")
school = input ("Enter your school name:")
degree = input ("Enter your degree:")
print()
# Out:
# Enter your name: Manikandababu
# Enter your age: 44
# Enter your school name: Velammal
# Enter your degree: BE

# %%
# Addition

# %%
a = 43
b = 34
print ("a=",a)
print ("b=",b)
Add = a+b
print ("Add=",Add)
# Out:
# a= 43
# b= 34
# Add= 77

# %%
# Substraction

# %%
a = 43
b = 34
print ("a=",a)
print ("b=",b)
sub = a-b
print ("sub=",sub)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
#Multiplication

# %%
a = 63
b = 97
print ("a=",a)
print ("b=",b)
mul= a*b
print ("Multiply=",mul)
# Out:
# a= 63
# b= 97
# Multiply= 6111

# %%
# Float Division

# %%
a = 76
b = 31
print ("a=",a)
print ("b=",b)
div = a/b
print ("Division=",div)
# Out:
# a= 76
# b= 31
# Division= 2.4516129032258065

# %%
# Floor Division

# %%
a = 76
b = 31
print ("a=",a)
print ("b=",b)
div = a//b
print ("Division=",div)
# Out:
# a= 76
# b= 31
# Division= 2

# %%
# Modulo

# %%
a = 76
b = 31
print ("a=",a)
print ("b=",b)
mod = a%b
print ("reminder=",mod)
# Out:
# a= 76
# b= 31
# reminder= 14

# %%
a=4
b=4
power = (4**4)
print ("a=",a)
print ("b=",b)
print ("Power=",power)
# Out:
# a= 4
# b= 4
# Power= 256
