# %%
# Problem 01 # Print Statement

# %%
print ("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
#Problem 02 # Add TWO Numbers

# %%
Num1=30
print ("Given number01=",Num1)
Num2=10
print ("Given number02=",Num2)
ADD = Num1+Num2
print ("The Answer is =",ADD)
# Out:
# Given number01= 30
# Given number02= 10
# The Answer is = 40

# %%
# Problem 03 # BMI Index

# %%
BMI=int(input("Enter your BMI Value:"))
if(BMI<18.5):
    print("UnderWeight")
elif(BMI<24.9):
    print("Healthy Weight")
elif(BMI<29.9):
    print("OverWeight")
elif(BMI>29.9):
    print("OBESE")
# Out:
# Enter your BMI Value: 40
# OBESE
